# %% [markdown]
# ---
# # DELL LEAD - Curso de Visualização de Dados 📊
#
# <b> Oficina - Aula 3.3 </b>
#
# Neste notebook iremos analisar os dados sobre a vendas mensais de shampoos durante um período de 3 anos, com o objetivo de colocar em prática as ferramentas aprendidas para análise de séries temporais.
#
# Por: Pedro Florencio de Almeida Neto
#
# ---

# %% [markdown]
# <b> (Questão 1) </b> Primeiro, importe as bibliotecas pandas, matplotlib e seaborn, e use a palavra mágica inline para exibir as visualizações no notebook. Depois, carregue os dados, que estão disponibilizados neste link: [dados](https://d11s0xq1vqg039.cloudfront.net/videos_conteudo/visual/micro07/oficina/arquivos/dadosoficina07.txt), em um DataFrame. Em seguida, você pode carregar os dados pela URI, ou salvá-los em sua máquina e carregá-los localmente;

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://d11s0xq1vqg039.cloudfront.net/videos_conteudo/visual/micro07/oficina/arquivos/dadosoficina07.txt')
df.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   36 non-null     object
#  1   Sales   36 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 704.0+ bytes

# %% [markdown]
# ---
# <b>(Questão 2) </b>Para o segundo e último passo, crie uma visualização que mostre a série temporal das vendas ao longo dos meses. Você pode, por exemplo, se perguntar se existe alguma tendência ou alguma periodicidade, OK?

# %%
plt.figure(figsize=(25,8))
sns.set_style('whitegrid')
plt.title('Vendas de Shampoos',fontdict={'fontsize':18})
sns.lineplot(x=df['Month'],y=df['Sales'],palette='inferno')
plt.xlabel('Meses',fontdict={'fontsize':14})
plt.ylabel('Vendas',fontdict={'fontsize':14})
plt.show()

# %% [markdown]
# <b> Observações sobre os dados: </b>
#
# * As coletas de dados sobre as vendas de shampoos foram feitas ao longo de 3 anos.
# * Houve uma tendência de crescimento nas vendas ao longo desses 3 anos.
# * Entre julho a outubro do primeiro ano houve uma queda nas vendas, chegando muito próximo do pior índice de vendas ao longo de todo o tempo analisado.
# * O maior índice de vendas ocorreu no mês de setembro do terceiro ano.

# %% [markdown]
# <b> Obrigado! </b>
#
# ---
