# %% [markdown]
# ---
# # DELL LEAD - Curso de Visualização de Dados 📊
#
# <b> Oficina - Aula 3.2 </b>
#
# Este notebook tem como objetivo analisar os dados sobre o consumo de galão de combustível por milha (miles per galon, mpg), número de cilindros, cilindrada, cavalos de potência, peso, aceleração, ano do modelo, país de origem e nome de determinados veículos presentes no dataset "mpg" embutido na biblioteca Seaborn. Colocaremos em prática as principais funções utilizadas para gráficos de dispersão (scatterplot).
#
# Por: Pedro Florencio de Almeida Neto
#
# ---

# %% [markdown]
# <b> (Questão 1) </b>Importe as bibliotecas pandas, matplotlib e seaborn, usando a palavra mágica inline, para exibir as visualizações no notebook. Carregue os dados, que podem ser carregados pelo seaborn, utilizando a função load_dataset(‘mpg’), em um DataFrame.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = sns.load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ---
# <b>(Questão 2) </b> Crie uma visualização que mostre a relação entre a aceleração (‘acceleration’) e o consumo de combustível (‘mpg’) dos veículos, em que seja possível diferenciar o país de origem (‘origin’). Sabendo disso, existe uma correlação entre a aceleração e o consumo? De que tipo? A correlação é a mesma para os diferentes países de origem? Você pode escolher a técnica que julgar mais adequada!

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='acceleration',y='mpg',hue='origin',data=df)
plt.title('Gráfico de dispersão da aceleração e consumo de veículos por país de origem')
plt.show()

# %%
sns.relplot(x='acceleration',y='mpg',col='origin',data=df)
plt.show()

# %%
sns.heatmap(df.corr(),cmap='viridis',annot=True,linewidths=1)
plt.show()

# %% [markdown]
# 🚗 É possível notar que há uma baixa correlação positiva entre consumo e aceleração dos carros deste conjunto de dados, principalmente se observarmos apenas os veículos de origem europeia. A melhor visualização fica por conta dos plots separados de cada país de origem aliado à matriz de correlação. As correlações entre cada um deles é diferente. Vamos ver se os carros europeus tem realmente a menor correlação?

# %%
print('Correlações\n')
print('Europa - {}'.format(df[df['origin']=='europe'].corr()['acceleration'].iloc[0]))
print('Japão - {}'.format(df[df['origin']=='japan'].corr()['acceleration'].iloc[0]))
print('EUA - {}'.format(df[df['origin']=='usa'].corr()['acceleration'].iloc[0]))
# Out:
# Correlações
#
# Europa - 0.2871464548828001
# Japão - 0.4011143077629134
# EUA - 0.3793370839357345

# %% [markdown]
# Exatamente isso!

# %% [markdown]
# ---
# <b>(Questão 3)</b> Crie uma visualização que mostre a relação entre a aceleração (‘acceleration’) e o consumo de combustível (‘mpg’) dos veículos, em que seja possível visualizar o ano do modelo (model_year). Existe alguma relação entre as três variáveis?

# %%
sns.lmplot(x='acceleration',y='mpg',data=df,hue='model_year',fit_reg=False)

# %% [markdown]
# 🚗 Bastante poluído de informações

# %%
sns.relplot(x='acceleration',y='mpg',col='model_year',data=df,col_wrap=3)
plt.show()

# %% [markdown]
# 🚗 As correlações para cada ano são diferentes entre si. Em alguns anos é possível notar alguma correlação positiva (71,72 e 78), entretanto em sua maioria podemos perceber baixíssima correlação.
#
# <b> Obrigado! </b>
#
# ---
