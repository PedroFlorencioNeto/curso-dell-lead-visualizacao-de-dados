# %% [markdown]
# ---
# # DELL LEAD - Curso de Visualização de Dados 📊
#
# <b> Oficina - Aula 4.1 </b>
#
# Neste notebook iremos analisar o dataset "Titanic", tendo como objetivo a visualização de múltiplas distribuições de dados categóricos, utilizando as bibliotecas Pandas, Matplotlib e Seaborn.
#
# Por: Pedro Florencio de Almeida Neto
#
# ---

# %% [markdown]
# <b>(Questão 1)</b> Importe as bibliotecas pandas, matplotlib e seaborn e use a palavra mágica inline, para exibir as visualizações no notebook. Depois, carregue os dados em um DataFrame. Os dados podem ser carregados pelo seaborn, utilizando a função load_dataset(‘titanic’)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ---
# <b>(Questão 2)</b> Crie uma visualização que mostre a distribuição do valor da passagem (“fare”), de acordo com a cidade na qual o passageiro embarcou ("embark_town"). Você pode escolher a técnica que julgar mais adequada

# %% [markdown]
# * <b>Opção 1: Gráfico de dispersão categórico</b>

# %%
plt.figure(figsize=(7,7))
sns.set_style('whitegrid')
sns.stripplot(x='embark_town',y='fare',data=df,palette='pastel')
plt.title('Gráfico 1 - Valores pagos de passagem por cidade',fontdict={'fontsize':15},pad=25)
plt.xlabel('Cidade',fontdict={'fontsize':12},labelpad=20)
plt.ylabel('Valor da passagem',fontdict={'fontsize':12},labelpad=20)
plt.show()

# %% [markdown]
# * <b>Opção 2: Gráfico de enxame (swarmplot)</b>

# %%
plt.figure(figsize=(7,7))
sns.set_style('whitegrid')
sns.swarmplot(x='embark_town',y='fare',data=df,palette='pastel')
plt.title('Gráfico 2 - Valores pagos de passagem por cidade',fontdict={'fontsize':15},pad=25)
plt.xlabel('Cidade',fontdict={'fontsize':12},labelpad=20)
plt.ylabel('Valor da passagem',fontdict={'fontsize':12},labelpad=20)
plt.show()

# %% [markdown]
# * <b>Opção 3: Gráfico de caixa (boxplot)</b>

# %%
plt.figure(figsize=(7,7))
sns.set_style('whitegrid')
sns.boxplot(x='embark_town',y='fare',data=df,palette='pastel')
plt.title('Gráfico 3 - Valores pagos de passagem por cidade',fontdict={'fontsize':15},pad=25)
plt.xlabel('Cidade',fontdict={'fontsize':12},labelpad=20)
plt.ylabel('Valor da passagem',fontdict={'fontsize':12},labelpad=20)
plt.yticks(ticks=np.arange(0,550,25))
plt.show()

# %% [markdown]
# * <b>Opção 4: Gráfico de caixa (boxplot) alternativo</b>

# %%
plt.figure(figsize=(7,7))
sns.set_style('whitegrid')
sns.boxenplot(x='embark_town',y='fare',data=df,palette='pastel')
plt.title('Gráfico 4 - Valores pagos de passagem por cidade',fontdict={'fontsize':15},pad=25)
plt.xlabel('Cidade',fontdict={'fontsize':12},labelpad=20)
plt.ylabel('Valor da passagem',fontdict={'fontsize':12},labelpad=20)
plt.yticks(ticks=np.arange(0,550,25))
plt.show()

# %% [markdown]
# * <b>Opção 5: Gráfico de violino (violinplot)</b>

# %%
plt.figure(figsize=(7,7))
sns.set_style('whitegrid')
sns.violinplot(x='embark_town',y='fare',data=df,palette='pastel')
plt.title('Gráfico 5 - Valores pagos de passagem por cidade',fontdict={'fontsize':15},pad=25)
plt.xlabel('Cidade',fontdict={'fontsize':12},labelpad=20)
plt.ylabel('Valor da passagem',fontdict={'fontsize':12},labelpad=20)
plt.show()

# %% [markdown]
# <b> Conclusões: </b>
# * Por conter muitos dados concentrados, o gráfico de enxame se mostrou melhor que o gráfico de dispersão categórico (stripplot).
# * O gráfico de violino por sua vez, deveria fornecer uma melhor visualização que os anteriores, já que estamos lidando com muitos dados. Entretanto, isso não ocorre para esse caso.
# * Podemos observar através do stripplot que Queenstown foi a cidade que menos pessoas embarcaram.
# * A distribuição de passagens mostra que há pouca dispersão no valor pago pelos passageiros, principalmente em Queenstown onde os valores dos quartis estão muito próximos da mediana (e abaixo de 25 dólares).
# * Através do boxplot, notamos que tivemos dezenas de passageiros são considerados outliers, isto é, pagaram passagem muito mais cara que foi pago pela maioria dos passageiros de suas respectivas cidades.

# %% [markdown]
# ---
# <b>(Questão 3)</b> Crie uma visualização que mostre as distribuições do valor da passagem, de acordo com a cidade de embarque, sexo e se o passageiro sobreviveu ou não. Você pode escolher a técnica que julgar mais adequada. Que diferença você consegue notar nas distribuições dos passageiros que sobreviveram em relação aos que não sobreviveram?

# %%
sns.catplot(x='embark_town',y='fare',hue='sex',col='survived',data=df,kind='swarm',palette='pastel')
plt.show()

# %% [markdown]
# Nota-se que sobreviveram mais mulheres do que homens, nas três cidades de embarque.
#
# <b> Obrigado! </b>
#
# ---
